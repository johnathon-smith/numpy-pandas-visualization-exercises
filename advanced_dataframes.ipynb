# %%
import numpy as np
import pandas as pd
from env import host, user, password

# %% [markdown]
# # Exercises 1

# %% [markdown]
# ### Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string

# %%
def get_db_url(user, host, password, database):
    url = f"mysql+pymysql://{user}:{password}@{host}/{database}"
    return url

# %% [markdown]
# ### Use your function to obtain a connection to the employees database.

# %%
employees_url = get_db_url(user, host, password, 'employees')
employees_query = "SELECT * FROM employees"

# %%
employees_df = pd.read_sql(employees_query, employees_url)
employees_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %% [markdown]
# ### Intentionally make a typo in the database url. What kind of error message do you see?

# %%
pd.read_sql(employees_query, "wrong_url")
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-5-6d94e7e802a5> in <module>
# ----> 1 pd.read_sql(employees_query, "wrong_url")
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     597     1           1  2010-11-12
#     598     """
# --> 599     pandas_sql = pandasSQL_builder(con)
#     600
#     601     if isinstance(pandas_sql, SQLiteDatabase):
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/sql.py in pandasSQL_builder(con, schema, meta, is_cursor)
#     784     # When support for DBAPI connections is removed,
#     785     # is_cursor should not be necessary.
# --> 786     con = _engine_builder(con)
#     787     if _is_sqlalchemy_connectable(con):
#     788         return SQLDatabase(con, schema=schema, meta=meta)
#
# ...

# %% [markdown]
# The error says it could not parse the URL from the URL string I gave it.

# %% [markdown]
# ### Intentionally make an error in your SQL query. What does the error message look like?

# %%
pd.read_sql("bad_sql", employees_url)

# %% [markdown]
# The error says that I have an error in my SQL syntax.

# %% [markdown]
# ### Read the employees and titles tables into two separate DataFrames.

# %%
employees_df = pd.read_sql(employees_query, employees_url)
employees_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
titles_query = "SELECT * FROM titles"
titles_df = pd.read_sql(titles_query, employees_url)
titles_df
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %% [markdown]
# ### How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
employees_df.shape
# Out:
# (300024, 6)

# %%
titles_df.shape
# Out:
# (443308, 4)

# %% [markdown]
# I see everything that I expected to see.

# %% [markdown]
# ### Display the summary statistics for each DataFrame.

# %%
employees_df.info()
employees_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
titles_df.info()
titles_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %% [markdown]
# ### How many unique titles are in the titles DataFrame?

# %%
titles_df.title.unique()
# Out:
# array(['Senior Engineer', 'Staff', 'Engineer', 'Senior Staff',
#        'Assistant Engineer', 'Technique Leader', 'Manager'], dtype=object)

# %%
len(titles_df.title.unique())
# Out:
# 7

# %% [markdown]
# ### What is the oldest date in the to_date column?

# %%
titles_df.to_date.sort_values().head(1)
# Out:
# 16064    1985-03-01
# Name: to_date, dtype: object

# %% [markdown]
# ### What is the most recent date in the to_date column?

# %% [markdown]
# I took most recent date to mean the most recent date that is less than or equal to today's date. Not anything after.

# %%
# Need to import date function from datetime module
from datetime import date
titles_df[titles_df.to_date <= date.today()].to_date.sort_values().tail(1)
# Out:
# 364701    2002-08-01
# Name: to_date, dtype: object

# %% [markdown]
# # Exercises 2

# %% [markdown]
# ### Copy the users and roles DataFrames from the examples above.

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# ### What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, how = 'right', left_on = 'role_id', right_on = 'id' )
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %% [markdown]
# ### What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, how = 'outer', left_on = 'role_id', right_on = 'id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %% [markdown]
# ### What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
users.drop("role_id", axis = 1)
# Out:
#    id   name
# 0   1    bob
# 1   2    joe
# 2   3  sally
# 3   4   adam
# 4   5   jane
# 5   6   mike

# %%
users.merge(roles, on = 'id', how = 'outer')
# Out:
#    id name_x  role_id     name_y
# 0   1    bob      1.0      admin
# 1   2    joe      2.0     author
# 2   3  sally      3.0   reviewer
# 3   4   adam      3.0  commenter
# 4   5   jane      NaN        NaN
# 5   6   mike      NaN        NaN

# %% [markdown]
# ### Load the mpg dataset from PyDataset.

# %%
from pydataset import data
mpg = data('mpg')

# %% [markdown]
# ### Output and read the documentation for the mpg dataset.

# %%
data('mpg', show_doc = True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# ### How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# ### Check out your column names and perform any cleanup you may want on them.

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
mpg.rename(columns = {'cty' : 'city', 'hwy':'highway', 'displ':'displacement (L)'}, inplace = True)

# %%
mpg
# Out:
#     manufacturer   model  displacement (L)  year  cyl       trans drv  city  \
# 1           audi      a4               1.8  1999    4    auto(l5)   f    18
# 2           audi      a4               1.8  1999    4  manual(m5)   f    21
# 3           audi      a4               2.0  2008    4  manual(m6)   f    20
# 4           audi      a4               2.0  2008    4    auto(av)   f    21
# 5           audi      a4               2.8  1999    6    auto(l5)   f    16
# ..           ...     ...               ...   ...  ...         ...  ..   ...
# 230   volkswagen  passat               2.0  2008    4    auto(s6)   f    19
# 231   volkswagen  passat               2.0  2008    4  manual(m6)   f    21
# 232   volkswagen  passat               2.8  1999    6    auto(l5)   f    16
# 233   volkswagen  passat               2.8  1999    6  manual(m5)   f    18
# 234   volkswagen  passat               3.6  2008    6    auto(s6)   f    17
#
#      highway fl    class
# 1         29  p  compact
# ...

# %% [markdown]
# ### Display the summary statistics for the dataset.

# %%
mpg.info()
mpg.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   manufacturer      234 non-null    object
#  1   model             234 non-null    object
#  2   displacement (L)  234 non-null    float64
#  3   year              234 non-null    int64
#  4   cyl               234 non-null    int64
#  5   trans             234 non-null    object
#  6   drv               234 non-null    object
#  7   city              234 non-null    int64
#  8   highway           234 non-null    int64
#  9   fl                234 non-null    object
#  10  class             234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB
#        displacement (L)         year         cyl        city     highway
# count        234.000000   234.000000  234.000000  234.000000  234.000000
# ...

# %% [markdown]
# ### How many different manufacturers are there?

# %%
manufacturers = mpg.manufacturer.unique()
manufacturers
# Out:
# array(['audi', 'chevrolet', 'dodge', 'ford', 'honda', 'hyundai', 'jeep',
#        'land rover', 'lincoln', 'mercury', 'nissan', 'pontiac', 'subaru',
#        'toyota', 'volkswagen'], dtype=object)

# %%
manufacturers.size
# Out:
# 15

# %% [markdown]
# ### How many different models are there?

# %%
models = mpg.model.unique()
models
# Out:
# array(['a4', 'a4 quattro', 'a6 quattro', 'c1500 suburban 2wd', 'corvette',
#        'k1500 tahoe 4wd', 'malibu', 'caravan 2wd', 'dakota pickup 4wd',
#        'durango 4wd', 'ram 1500 pickup 4wd', 'expedition 2wd',
#        'explorer 4wd', 'f150 pickup 4wd', 'mustang', 'civic', 'sonata',
#        'tiburon', 'grand cherokee 4wd', 'range rover', 'navigator 2wd',
#        'mountaineer 4wd', 'altima', 'maxima', 'pathfinder 4wd',
#        'grand prix', 'forester awd', 'impreza awd', '4runner 4wd',
#        'camry', 'camry solara', 'corolla', 'land cruiser wagon 4wd',
#        'toyota tacoma 4wd', 'gti', 'jetta', 'new beetle', 'passat'],
#       dtype=object)

# %%
models.size
# Out:
# 38

# %% [markdown]
# ### Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg["mileage_difference"] = mpg.highway - mpg.city
mpg
# Out:
#     manufacturer   model  displacement (L)  year  cyl       trans drv  city  \
# 1           audi      a4               1.8  1999    4    auto(l5)   f    18
# 2           audi      a4               1.8  1999    4  manual(m5)   f    21
# 3           audi      a4               2.0  2008    4  manual(m6)   f    20
# 4           audi      a4               2.0  2008    4    auto(av)   f    21
# 5           audi      a4               2.8  1999    6    auto(l5)   f    16
# ..           ...     ...               ...   ...  ...         ...  ..   ...
# 230   volkswagen  passat               2.0  2008    4    auto(s6)   f    19
# 231   volkswagen  passat               2.0  2008    4  manual(m6)   f    21
# 232   volkswagen  passat               2.8  1999    6    auto(l5)   f    16
# 233   volkswagen  passat               2.8  1999    6  manual(m5)   f    18
# 234   volkswagen  passat               3.6  2008    6    auto(s6)   f    17
#
#      highway fl    class  mileage_difference
# ...

# %% [markdown]
# ### Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.highway + mpg.city) / 2
mpg
# Out:
#     manufacturer   model  displacement (L)  year  cyl       trans drv  city  \
# 1           audi      a4               1.8  1999    4    auto(l5)   f    18
# 2           audi      a4               1.8  1999    4  manual(m5)   f    21
# 3           audi      a4               2.0  2008    4  manual(m6)   f    20
# 4           audi      a4               2.0  2008    4    auto(av)   f    21
# 5           audi      a4               2.8  1999    6    auto(l5)   f    16
# ..           ...     ...               ...   ...  ...         ...  ..   ...
# 230   volkswagen  passat               2.0  2008    4    auto(s6)   f    19
# 231   volkswagen  passat               2.0  2008    4  manual(m6)   f    21
# 232   volkswagen  passat               2.8  1999    6    auto(l5)   f    16
# 233   volkswagen  passat               2.8  1999    6  manual(m5)   f    18
# 234   volkswagen  passat               3.6  2008    6    auto(s6)   f    17
#
# ...

# %% [markdown]
# ### Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg["is_automatic"] = mpg.trans.str.contains('auto') == True
mpg
# Out:
#     manufacturer   model  displacement (L)  year  cyl       trans drv  city  \
# 1           audi      a4               1.8  1999    4    auto(l5)   f    18
# 2           audi      a4               1.8  1999    4  manual(m5)   f    21
# 3           audi      a4               2.0  2008    4  manual(m6)   f    20
# 4           audi      a4               2.0  2008    4    auto(av)   f    21
# 5           audi      a4               2.8  1999    6    auto(l5)   f    16
# ..           ...     ...               ...   ...  ...         ...  ..   ...
# 230   volkswagen  passat               2.0  2008    4    auto(s6)   f    19
# 231   volkswagen  passat               2.0  2008    4  manual(m6)   f    21
# 232   volkswagen  passat               2.8  1999    6    auto(l5)   f    16
# 233   volkswagen  passat               2.8  1999    6  manual(m5)   f    18
# 234   volkswagen  passat               3.6  2008    6    auto(s6)   f    17
#
# ...

# %% [markdown]
# ### Using the mpg dataset, find out which manufacturer has the best miles per gallon on average?

# %%
mpg.groupby('manufacturer').average_mileage.agg('mean').sort_values().tail(1)
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %% [markdown]
# ### Do automatic or manual cars have better miles per gallon?

# %%
mpg.groupby('is_automatic').average_mileage.agg('mean').sort_values()
# Out:
# is_automatic
# True     19.130573
# False    22.227273
# Name: average_mileage, dtype: float64

# %% [markdown]
# # Exercises 3

# %% [markdown]
# ### Use your get_db_url function to help you explore the data from the chipotle database.

# %%
chipotle_url = get_db_url(user, host, password, 'chipotle')
chipotle_query = "SELECT * FROM orders"
chipotle = pd.read_sql(chipotle_query, chipotle_url)
chipotle
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %% [markdown]
# ### What is the total price for each order?

# %%
#First, I need to change the string values in item_price to floats
chipotle.item_price = chipotle.item_price.str.replace('$', '').astype(float)

# %%
chipotle
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
chipotle.groupby('order_id').item_price.sum()
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %% [markdown]
# ### What are the most popular 3 items?

# %%
chipotle.groupby('item_name').quantity.sum().sort_values().tail(3)
# Out:
# item_name
# Chips and Guacamole    506
# Chicken Burrito        591
# Chicken Bowl           761
# Name: quantity, dtype: int64

# %% [markdown]
# ### Which item has produced the most revenue?

# %%
chipotle['revenue'] = chipotle.item_price * chipotle.quantity
chipotle
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
chipotle.groupby('item_name').revenue.sum().idxmax()
# Out:
# 'Chicken Bowl'

# %% [markdown]
# ### Join the employees and titles DataFrames together.

# %%
employee_titles = employees_df.merge(titles_df, how = 'inner', on = 'emp_no')
employee_titles
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %% [markdown]
# ### For each title, find the hire date of the employee that was hired most recently with that title.

# %%
employee_titles.groupby('title').hire_date.max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %% [markdown]
# ### Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
#First, we need the department number for each employee and the department names
#I'll create a SQL query that joins the two associated tables and then pull the data into pandas
dept_query = '''
    SELECT emp_no, dept_emp.dept_no, dept_name
    FROM dept_emp
    JOIN departments ON departments.dept_no = dept_emp.dept_no;
'''

# %%
departments = pd.read_sql(dept_query, employees_url)
departments
# Out:
#         emp_no dept_no         dept_name
# 0        10011    d009  Customer Service
# 1        10038    d009  Customer Service
# 2        10049    d009  Customer Service
# 3        10060    d009  Customer Service
# 4        10088    d009  Customer Service
# ...        ...     ...               ...
# 331598  499976    d007             Sales
# 331599  499980    d007             Sales
# 331600  499986    d007             Sales
# 331601  499987    d007             Sales
# 331602  499988    d007             Sales
#
# [331603 rows x 3 columns]

# %%
employee_titles_depts = employee_titles.merge(departments, how = 'inner', on = 'emp_no')
employee_titles_depts
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 489898  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 489899  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 489900  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 489901  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 489902  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date dept_no    dept_name
# 0       Senior Engineer  1986-06-26  9999-01-01    d005  Development
# ...

# %%
#I accidentally solved this the wrong way the first time. Here, I counted the number of unique titles in each 
#department by using groupby
employee_titles_depts.groupby('dept_name').title.nunique()
# Out:
# dept_name
# Customer Service      7
# Development           7
# Finance               3
# Human Resources       3
# Marketing             3
# Production            7
# Quality Management    5
# Research              7
# Sales                 3
# Name: title, dtype: int64

# %%
#I think this is actually what the problem was asking for. This gives the total number of titles ever given
#in each department
pd.crosstab(employee_titles_depts.dept_name, employee_titles_depts.title)
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                   298      2362        4             2027
# Development                       7769     58135        2            49326
# Finance                              0         0        2                0
# Human Resources                      0         0        2                0
# Marketing                            0         0        2                0
# Production                        6445     49649        4            42205
# Quality Management                1831     13852        4            11864
# Research                           378      2986        2             2570
# Sales                                0         0        2                0
#
# title               Senior Staff  Staff  Technique Leader
# dept_name
# Customer Service           13925  16150               309
# Development                 1247   1424              7683
# ...
